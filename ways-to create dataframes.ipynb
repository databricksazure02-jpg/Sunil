# %%
dict_df=[{'id':1,'name':'John','dept':'IT','salary':10000,'address':'NY'},
        {'id':2,'name':'Mary','dept':'HR','salary':20000,'address':'LA'},
        {'id':3,'name':'Mike','dept':'IT','salary':30000,'address':'NY'},
        {'id':4,'name':'Sara','dept':'HR','salary':40000,'address':'LA'},
        {'id':5,'name':'Paul','dept':'IT','salary':50000,'address':'NY'}]
         
df=spark.createDataFrame(dict_df)
df.display()
df.show(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       3         {'id':3,'name':'Mike','dept':'IT','salary':30000,'address':'NY'},
#       4         {'id':4,'name':'Sara','dept':'HR','salary':40000,'address':'LA'},
#       5         {'id':5,'name':'Paul','dept':'IT','salary':50000,'address':'NY'}]
#       6
# ----> 7 df=spark.createDataFrame(dict_df)
#       8 df.display()
#       9 df.show(3)
#
# NameError: name 'spark' is not defined

# %%
df_file=spark.read.format('csv').option("header", "true").load("/Volumes/sunil/sunilk/sunilkl/emp_details.csv")
# display(df_file)
df_file.columns
# Out:
# ['id', 'name', 'age', 'department', 'salary']

# %%
from pyspark.sql.functions import col,expr,lit,concat,concat_ws,first,last
# df_file.select(col('name').alias('sunil')).show()
# df_file.select(df_file.salary.alias('sunil')).show()
display(df_file)
df_file.filter('salary >50000 as high').show()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_file.withColumn('sunil', concat(df_file.age,lit('*'),df_file.salary)).show()
new=df_file.withColumn('sunil', concat_ws(' ',df_file.age,df_file.salary).cast('struct'))
new.select(new.age,col('sunil')[0]).show()
# Out:
# +---+------+---+----------+------+--------+
# | id|  name|age|department|salary|   sunil|
# +---+------+---+----------+------+--------+
# |  1| Sunil| 28|        IT| 55000|28*55000|
# |  2| Priya| 32|        HR| 48000|32*48000|
# |  3|  Amit| 29|   Finance| 60000|29*60000|
# |  4|  Neha| 26| Marketing| 45000|26*45000|
# |  5|Rajesh| 35|        IT| 72000|35*72000|
# |  6| Sneha| 30|   Finance| 58000|30*58000|
# |  7| Karan| 27|        HR| 50000|27*50000|
# |  8| Pooja| 31| Marketing| 53000|31*53000|
# |  9|  Anil| 40|        IT| 80000|40*80000|
# | 10| Meera| 25|   Finance| 47000|25*47000|
# +---+------+---+----------+------+--------+
# ---------------------------------------------------------------------------
# ParseException                            Traceback (most recent call last)
# File <command-5228794179556390>, line 3
#       1 df_file.withColumn('sunil', concat(df_file.age,lit('*'),df_file.salary)).show()
# ...

# %%
df_file.withColumn('salary',(col('salary')+10000)).show()
display(df_file)
# Out:
# +---+------+---+----------+------+
# | id|  name|age|department|salary|
# +---+------+---+----------+------+
# |  1| Sunil| 28|        IT| 65000|
# |  2| Priya| 32|        HR| 58000|
# |  3|  Amit| 29|   Finance| 70000|
# |  4|  Neha| 26| Marketing| 55000|
# |  5|Rajesh| 35|        IT| 82000|
# |  6| Sneha| 30|   Finance| 68000|
# |  7| Karan| 27|        HR| 60000|
# |  8| Pooja| 31| Marketing| 63000|
# |  9|  Anil| 40|        IT| 90000|
# | 10| Meera| 25|   Finance| 57000|
# +---+------+---+----------+------+
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_file.drop("age").show()
display(df_file)
# Out:
# +---+------+----------+------+
# | id|  name|department|salary|
# +---+------+----------+------+
# |  1| Sunil|        IT| 55000|
# |  2| Priya|        HR| 48000|
# |  3|  Amit|   Finance| 60000|
# |  4|  Neha| Marketing| 45000|
# |  5|Rajesh|        IT| 72000|
# |  6| Sneha|   Finance| 58000|
# |  7| Karan|        HR| 50000|
# |  8| Pooja| Marketing| 53000|
# |  9|  Anil|        IT| 80000|
# | 10| Meera|   Finance| 47000|
# +---+------+----------+------+
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_file.show()
adress_df=df_file.withColumn('adress',lit(None))
adress_df.show()
# adress_df.fillna(5).show()
# adress_df.na.fill(5).show()
# Out:
# +---+------+---+----------+------+
# | id|  name|age|department|salary|
# +---+------+---+----------+------+
# |  1| Sunil| 28|        IT| 55000|
# |  2| Priya| 32|        HR| 48000|
# |  3|  Amit| 29|   Finance| 60000|
# |  4|  Neha| 26| Marketing| 45000|
# |  5|Rajesh| 35|        IT| 72000|
# |  6| Sneha| 30|   Finance| 58000|
# |  7| Karan| 27|        HR| 50000|
# |  8| Pooja| 31| Marketing| 53000|
# |  9|  Anil| 40|        IT| 80000|
# | 10| Meera| 25|   Finance| 47000|
# +---+------+---+----------+------+
#
# +---+------+---+----------+------+------+
# | id|  name|age|department|salary|adress|
# +---+------+---+----------+------+------+
# |  1| Sunil| 28|        IT| 55000|  NULL|
# |  2| Priya| 32|        HR| 48000|  NULL|
# |  3|  Amit| 29|   Finance| 60000|  NULL|
# |  4|  Neha| 26| Marketing| 45000|  NULL|
# |  5|Rajesh| 35|        IT| 72000|  NULL|
# |  6| Sneha| 30|   Finance| 58000|  NULL|
# |  7| Karan| 27|        HR| 50000|  NULL|
# ...

# %%
# adress_df.show()
# adress_df.fillna('3').show()
adress_df.dropna().show()
# adress_df.na.drop().show()
# adress_df.na.drop('any').show()
# adress_df.na.drop('all').show()
# adress_df.na.drop('any',subset=['age']).show()

adress_df.select(first('age')).show()
#
# Out:
# +---+----+---+----------+------+------+
# | id|name|age|department|salary|adress|
# +---+----+---+----------+------+------+
# +---+----+---+----------+------+------+
#
# +----------+
# |first(age)|
# +----------+
# |        28|
# +----------+
